# %%
import re
def clean_text(text):
    text = re.sub(r"\n", " ", text)  # Replace newline characters with spaces
    return text.strip()  # Remo

# %%
from google.cloud import vision
def detect_text(path):

    """Detects text in the file."""

    client = vision.ImageAnnotatorClient()

    with io.open(path, "rb") as image_file:
        content = image_file.read()

    image = vision.Image(content=content)

    response = client.text_detection(image=image)
    if response.error.message:
        raise Exception(
            "{}\nFor more info on error messages, check: "
            "https://cloud.google.com/apis/design/errors".format(response.error.message)
        )
    texts = response.text_annotations[0]
    texts_cleaned = clean_text(texts.description)
    detected_language = texts.locale

    print("texts_cleaned: ", texts_cleaned)
    return texts_cleaned, detected_language

# %%
detect_text("/Users/keonhongkoo/Downloads/test2.png")
# Out:
# texts_cleaned:  FPN + Mask R-CNN 15:12M(1/32) Instance Detection FPN + Mask R-CNN A₁25x1/my 3:125(1/8) P21x256x14 P Instance Detection PS:1x29(12) FPN + Mask R-CNN Ax256x(1/16) P3:1x256a(18) P21x256x1/4) PRIx256 (132) Instance Detection F 2361/16 /P3:1x256x(1/8) P_182%A11/1 FPN+Mask R-CNN Instance Detection Kommy /F28y IN Class, S Instance Mask IN Instance Mask Projection Instance Mask - Project 1xD(14) Box,Class, Sco BON-1 IxNx28x28 (a) Mask R-CNN-IMP Semantic Segmentation Module 878-1 IN C (b) Panoptic-P2 Instance Mask Projection Instance Mask Bilox,Clas, Scon lace Mak E-Project IxNxx8 IxCx(146) concal Semantic Segmentation Module 4x up Semantic Segmentation Result Semantic Segmentation Head 4x conv3 + 1x convl + 4x up Semantic Segmentation Result Semantic Segmentation Head 4x conv3+ 1x convl + ¹4x up (c) Panoptic-P2-IMP Semantic Segmentation Result Semantic Segmentation 14x3+ 1x com 1 + 4x sp Semantic Segmentation Module Semantic Segmentation Result (d) Panoptic-FPN Figure 3: Vari
# ...

# %%
from google.cloud import translate

def translate_text(text, language, project_id="myproject-capston"):
    """Translating Text."""

    client = translate.TranslationServiceClient()

    location = "global"

    parent = f"projects/{project_id}/locations/{location}"

    # Translate text from English to French
    # Detail on supported types can be found here:
    # https://cloud.google.com/translate/docs/supported-formats
    if language != "ko":
        response = client.translate_text(
            request={
                "parent": parent,
                "contents": [text],
                "mime_type": "text/plain",  # mime types: text/plain, text/html
                "source_language_code": "en-US",
                "target_language_code": "ko",
            }
        )
        print("번역에서 얻은 response: ", response)

        # Display the translation for each input text provided
        for translation in response.translations:
            print("Translated text: {}".format(translation.translated_text))
        return translation.translated_text
    return text

# %%
response,lang = detect_text("/Users/keonhongkoo/Downloads/test2.png")
translate_text(text=response, language=lang)
# Out:
# texts_cleaned:  FPN + Mask R-CNN 15:12M(1/32) Instance Detection FPN + Mask R-CNN A₁25x1/my 3:125(1/8) P21x256x14 P Instance Detection PS:1x29(12) FPN + Mask R-CNN Ax256x(1/16) P3:1x256a(18) P21x256x1/4) PRIx256 (132) Instance Detection F 2361/16 /P3:1x256x(1/8) P_182%A11/1 FPN+Mask R-CNN Instance Detection Kommy /F28y IN Class, S Instance Mask IN Instance Mask Projection Instance Mask - Project 1xD(14) Box,Class, Sco BON-1 IxNx28x28 (a) Mask R-CNN-IMP Semantic Segmentation Module 878-1 IN C (b) Panoptic-P2 Instance Mask Projection Instance Mask Bilox,Clas, Scon lace Mak E-Project IxNxx8 IxCx(146) concal Semantic Segmentation Module 4x up Semantic Segmentation Result Semantic Segmentation Head 4x conv3 + 1x convl + 4x up Semantic Segmentation Result Semantic Segmentation Head 4x conv3+ 1x convl + ¹4x up (c) Panoptic-P2-IMP Semantic Segmentation Result Semantic Segmentation 14x3+ 1x com 1 + 4x sp Semantic Segmentation Module Semantic Segmentation Result (d) Panoptic-FPN Figure 3: Vari
# ...

# %%
detect_text("/Users/keonhongkoo/Downloads/test2.png")
# Out:
# "FPN + Mask R-CNN
# 15:12M(1/32)
# Instance Detection
# FPN + Mask R-CNN
# A₁25x1/my
# 3:125(1/8)
# P21x256x14
# P
# Instance Detection
# PS:1x29(12)
# FPN + Mask R-CNN
# Ax256x(1/16)
# P3:1x256a(18)
# P21x256x1/4)
# PRIx256 (132)
# Instance Detection
# F
# 2361/16
# /P3:1x256x(1/8)
# P_182%A11/1
# FPN+Mask R-CNN
# Instance Detection
# Kommy
# /F28y
# IN
# Class, S
# Instance Mask
# IN
# Instance Mask Projection
# Instance Mask
# - Project
# 1xD(14)
# Box,Class, Sco
# BON-1
# IxNx28x28
# (a) Mask R-CNN-IMP
# Semantic Segmentation Module
# 878-1
# IN C
# (b) Panoptic-P2
# Instance Mask Projection
# Instance Mask
# Bilox,Clas, Scon
# lace Mak
# E-Project
# IxNxx8
# IxCx(146)
# concal
# Semantic Segmentation Module
# 4x up
# Semantic Segmentation Result
# Semantic
# Segmentation Head
# 4x conv3 +
# 1x convl +
# 4x up
# Semantic Segmentation Result
# Semantic Segmentation
# Head
# 4x conv3+
# 1x convl +
# ¹4x up
# (c) Panoptic-P2-IMP
# Semantic Segmentation Result
# ...
