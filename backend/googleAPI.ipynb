# %%
from google.cloud import vision

# %%
def detect_text(path):
    """Detects text in the file."""
    from google.cloud import vision
    import io
    client = vision.ImageAnnotatorClient()

    with io.open(path, 'rb') as image_file:
        content = image_file.read()

    image = vision.Image(content=content)

    response = client.text_detection(image=image)
    texts = response.text_annotations
    return texts[0].description
    # print('Texts:', texts[0].description) #이정도면 내가 원하는 결과일까...
    
    #결론을 정리해보면 texts안에는 여러 text가 있는데 각 text마다 description과 bounding_poly가 있고 그 안에 좌표에 해당하는 것들이 있다.

    # for text in texts:
    #     print('\n"{}"'.format(text.description))
    #     print("----------------------------------------------")

        # vertices = (['({},{})'.format(vertex.x, vertex.y)
        #             for vertex in text.bounding_poly.vertices])

        # print('bounds: {}'.format(','.join(vertices)))

    if response.error.message:
        raise Exception(
            '{}\nFor more info on error messages, check: '
            'https://cloud.google.com/apis/design/errors'.format(
                response.error.message))

# %%
# Imports the Google Cloud Translation library
from google.cloud import translate

# Initialize Translation client
def translate_text(text, project_id="myproject-capston"):
    """Translating Text."""

    client = translate.TranslationServiceClient()

    location = "global"

    parent = f"projects/{project_id}/locations/{location}"

    # Translate text from English to French
    # Detail on supported types can be found here:
    # https://cloud.google.com/translate/docs/supported-formats
    response = client.translate_text(
        request={
            "parent": parent,
            "contents": [text],
            "mime_type": "text/plain",  # mime types: text/plain, text/html
            "source_language_code": "en-US",
            "target_language_code": "ko",
        }
    )

    # Display the translation for each input text provided
    for translation in response.translations:
        print("Translated text: {}".format(translation.translated_text))

# %%
response = detect_text("http://localhost:8000/media/instagram/post/2023/03/17/R1280x0-5.png")
translate_text(text=response)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 response = detect_text("http://localhost:8000/media/instagram/post/2023/03/17/R1280x0-5.png")
#       2 translate_text(text=response)
#
# Cell In[22], line 7, in detect_text(path)
#       4 import io
#       5 client = vision.ImageAnnotatorClient()
# ----> 7 with io.open(path, 'rb') as image_file:
#       8     content = image_file.read()
#      10 image = vision.Image(content=content)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'http://localhost:8000/media/instagram/post/2023/03/17/R1280x0-5.png'

# %%
detect_text("/Users/keonhongkoo/Downloads/test2.png")
# Out:
# "FPN + Mask R-CNN
# 15:12M(1/32)
# Instance Detection
# FPN + Mask R-CNN
# A₁25x1/my
# 3:125(1/8)
# P21x256x14
# P
# Instance Detection
# PS:1x29(12)
# FPN + Mask R-CNN
# Ax256x(1/16)
# P3:1x256a(18)
# P21x256x1/4)
# PRIx256 (132)
# Instance Detection
# F
# 2361/16
# /P3:1x256x(1/8)
# P_182%A11/1
# FPN+Mask R-CNN
# Instance Detection
# Kommy
# /F28y
# IN
# Class, S
# Instance Mask
# IN
# Instance Mask Projection
# Instance Mask
# - Project
# 1xD(14)
# Box,Class, Sco
# BON-1
# IxNx28x28
# (a) Mask R-CNN-IMP
# Semantic Segmentation Module
# 878-1
# IN C
# (b) Panoptic-P2
# Instance Mask Projection
# Instance Mask
# Bilox,Clas, Scon
# lace Mak
# E-Project
# IxNxx8
# IxCx(146)
# concal
# Semantic Segmentation Module
# 4x up
# Semantic Segmentation Result
# Semantic
# Segmentation Head
# 4x conv3 +
# 1x convl +
# 4x up
# Semantic Segmentation Result
# Semantic Segmentation
# Head
# 4x conv3+
# 1x convl +
# ¹4x up
# (c) Panoptic-P2-IMP
# Semantic Segmentation Result
# ...
